# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("netflix_data.csv")
data
# Out:
#                       Title                              Genre Languages  \
# 0     Gilberts Grim Revenge     Documentary, Biography, Comedy   English
# 1           Midnight Family  Documentary, Action, Crime, Drama   Spanish
# 2        Pick of the Litter                        Documentary   English
# 3            Whose Streets?                        Documentary   English
# 4             I Will Follow                              Drama   English
# ...                     ...                                ...       ...
# 2113           Fear Dot Com            Crime, Horror, Thriller   English
# 2114         Daddy Day Camp                     Comedy, Family   English
# 2115        Son of the Mask            Comedy, Family, Fantasy   English
# 2116      Battlefield Earth          Action, Adventure, Sci-Fi   English
# 2117          Baby Geniuses      Comedy, Crime, Family, Sci-Fi   English
#
#      Series or Movie  Hidden Gem Score  \
# 0              Movie               8.7
# ...

# %%
data.shape
# Out:
# (2118, 28)

# %%
data.size
# Out:
# 59304

# %%
data.columns
# Out:
# Index(['Title', 'Genre', 'Languages', 'Series or Movie', 'Hidden Gem Score',
#        'Country Availability', 'Runtime', 'Director', 'Writer', 'Actors',
#        'View Rating', 'IMDb Score', 'Rotten Tomatoes Score',
#        'Metacritic Score', 'Awards Received', 'Awards Nominated For',
#        'Boxoffice (Dollar)', 'Release Date', 'Netflix Release Date',
#        'Production House', 'Netflix Link', 'IMDb Link', 'Summary',
#        'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer', 'Trailer Site'],
#       dtype='object')

# %%
data.info
# Out:
# <bound method DataFrame.info of                       Title                              Genre Languages  \
# 0     Gilberts Grim Revenge     Documentary, Biography, Comedy   English
# 1           Midnight Family  Documentary, Action, Crime, Drama   Spanish
# 2        Pick of the Litter                        Documentary   English
# 3            Whose Streets?                        Documentary   English
# 4             I Will Follow                              Drama   English
# ...                     ...                                ...       ...
# 2113           Fear Dot Com            Crime, Horror, Thriller   English
# 2114         Daddy Day Camp                     Comedy, Family   English
# 2115        Son of the Mask            Comedy, Family, Fantasy   English
# 2116      Battlefield Earth          Action, Adventure, Sci-Fi   English
# 2117          Baby Geniuses      Comedy, Crime, Family, Sci-Fi   English
#
#      Series or Movie  Hidden Gem Score  \
# ...

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#                       Title                              Genre Languages  \
# 0     Gilberts Grim Revenge     Documentary, Biography, Comedy   English
# 1           Midnight Family  Documentary, Action, Crime, Drama   Spanish
# 2        Pick of the Litter                        Documentary   English
# 3            Whose Streets?                        Documentary   English
# 4             I Will Follow                              Drama   English
# ...                     ...                                ...       ...
# 2113           Fear Dot Com            Crime, Horror, Thriller   English
# 2114         Daddy Day Camp                     Comedy, Family   English
# 2115        Son of the Mask            Comedy, Family, Fantasy   English
# 2116      Battlefield Earth          Action, Adventure, Sci-Fi   English
# 2117          Baby Geniuses      Comedy, Crime, Family, Sci-Fi   English
#
#      Series or Movie  Hidden Gem Score  \
# 0              Movie               8.7
# ...

# %%
data.isnull().sum()
# Out:
# Title                    0
# Genre                    0
# Languages                0
# Series or Movie          0
# Hidden Gem Score         0
# Country Availability     0
# Runtime                  0
# Director                 0
# Writer                   0
# Actors                   0
# View Rating              0
# IMDb Score               0
# Rotten Tomatoes Score    0
# Metacritic Score         0
# Awards Received          0
# Awards Nominated For     0
# Boxoffice (Dollar)       0
# Release Date             0
# Netflix Release Date     0
# Production House         0
# Netflix Link             0
# IMDb Link                0
# Summary                  0
# IMDb Votes               0
# Image                    0
# Poster                   0
# TMDb Trailer             0
# Trailer Site             0
# dtype: int64

# %% [markdown]
# # How many

# %%
data["Date_F"] = pd.to_datetime(data["Release Date"])
data
# Out:
#                       Title                              Genre Languages  \
# 0     Gilberts Grim Revenge     Documentary, Biography, Comedy   English
# 1           Midnight Family  Documentary, Action, Crime, Drama   Spanish
# 2        Pick of the Litter                        Documentary   English
# 3            Whose Streets?                        Documentary   English
# 4             I Will Follow                              Drama   English
# ...                     ...                                ...       ...
# 2113           Fear Dot Com            Crime, Horror, Thriller   English
# 2114         Daddy Day Camp                     Comedy, Family   English
# 2115        Son of the Mask            Comedy, Family, Fantasy   English
# 2116      Battlefield Earth          Action, Adventure, Sci-Fi   English
# 2117          Baby Geniuses      Comedy, Crime, Family, Sci-Fi   English
#
#      Series or Movie  Hidden Gem Score  \
# 0              Movie               8.7
# ...

# %%
years = data["Date_F"].dt.year.value_counts()
years
# Out:
# 2017    144
# 2016    133
# 2018    129
# 2014    122
# 2015    116
#        ...
# 1970      1
# 1939      1
# 1965      1
# 1951      1
# 1936      1
# Name: Date_F, Length: 62, dtype: int64

# %%
# %matplotlib inline
years.plot(kind='bar', figsize=(15,8))
plt.xlabel("Years")
plt.ylabel("Total Movies")
plt.legend(["Counts of Movies"])

# %%
data.groupby('Genre').Genre.count()
# Out:
# Genre
# Action, Adventure                                                          10
# Action, Adventure, Biography, Crime, Fantasy, Horror, Mystery, Thriller     1
# Action, Adventure, Biography, Drama                                         1
# Action, Adventure, Biography, Drama, History                                1
# Action, Adventure, Biography, Drama, Thriller                               1
#                                                                            ..
# Romance, Sci-Fi, Thriller                                                   1
# Sci-Fi, Thriller                                                            3
# Thriller                                                                    4
# War, Drama, Action, Romance                                                 1
# Western                                                                     2
# Name: Genre, Length: 555, dtype: int64

# %%
data.groupby('Genre').Genre.count().rank()
# Out:
# Genre
# Action, Adventure                                                          517.0
# Action, Adventure, Biography, Crime, Fantasy, Horror, Mystery, Thriller    151.5
# Action, Adventure, Biography, Drama                                        151.5
# Action, Adventure, Biography, Drama, History                               151.5
# Action, Adventure, Biography, Drama, Thriller                              151.5
#                                                                            ...
# Romance, Sci-Fi, Thriller                                                  151.5
# Sci-Fi, Thriller                                                           421.5
# Thriller                                                                   456.0
# War, Drama, Action, Romance                                                151.5
# Western                                                                    352.5
# Name: Genre, Length: 555, dtype: float64

# %%
data.groupby('Series or Movie').count()
# Out:
#                  Title  Genre  Languages  Hidden Gem Score  \
# Series or Movie
# Movie             2118   2118       2118              2118
#
#                  Country Availability  Runtime  Director  Writer  Actors  \
# Series or Movie
# Movie                            2118     2118      2118    2118    2118
#
#                  View Rating  ...  Production House  Netflix Link  IMDb Link  \
# Series or Movie               ...
# Movie                   2118  ...              2118          2118       2118
#
#                  Summary  IMDb Votes  Image  Poster  TMDb Trailer  \
# Series or Movie
# Movie               2118        2118   2118    2118          2118
#
#                  Trailer Site  Date_F
# Series or Movie
# Movie                    2118    2118
#
# [1 rows x 28 columns]

# %%
data.groupby('Languages').Languages.count()
# Out:
# Languages
# American Sign Language, English    1
# Arabic                             1
# Arabic, English                    1
# Cantonese                          1
# Cantonese, English                 1
#                                   ..
# Tamil, French, English             1
# Thai, English                      1
# Tswana, English                    1
# Yiddish, English, Spanish          1
# Zulu, Afrikaans, Xhosa, English    1
# Name: Languages, Length: 489, dtype: int64

# %%
data[data['Genre'] == 'Action']
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Languages, Series or Movie, Hidden Gem Score, Country Availability, Runtime, Director, Writer, Actors, View Rating, IMDb Score, Rotten Tomatoes Score, Metacritic Score, Awards Received, Awards Nominated For, Boxoffice (Dollar), Release Date, Netflix Release Date, Production House, Netflix Link, IMDb Link, Summary, IMDb Votes, Image, Poster, TMDb Trailer, Trailer Site, Date_F]
# Index: []
#
# [0 rows x 29 columns]

# %%
data[ (data['Genre']=='Action, Adventure')]
# Out:
#                                                   Title              Genre  \
# 64                                       The Dead Lands  Action, Adventure
# 183       Indiana Jones and the Raiders of the Lost Ark  Action, Adventure
# 319                               The Dark Knight Rises  Action, Adventure
# 600                  Indiana Jones and the Last Crusade  Action, Adventure
# 625                                       Batman Begins  Action, Adventure
# 891                Indiana Jones and the Temple of Doom  Action, Adventure
# 936                                              Batman  Action, Adventure
# 1100  Indiana Jones and the Kingdom of the Crystal S...  Action, Adventure
# 1323                                           Big Game  Action, Adventure
# 1773                                     Batman Forever  Action, Adventure
#
#                                              Languages Series or Movie  \
# ...

# %%
data[ (data['Genre']=='Action, Adventure, Biography, Crime, Fantasy, Horror, Mystery, Thriller')]
# Out:
#                      Title                                              Genre  \
# 1838  Deliver Us from Evil  Action, Adventure, Biography, Crime, Fantasy, ...
#
#                              Languages Series or Movie  Hidden Gem Score  \
# 1838  English, Spanish, Latin, Italian           Movie               2.2
#
#                                    Country Availability   Runtime  \
# 1838  Switzerland,Belgium,United Kingdom,Hong Kong,T...  1-2 hour
#
#               Director                                             Writer  \
# 1838  Scott Derrickson  Scott Derrickson, Ralph Sarchie, Lisa Collier ...
#
#                                                 Actors  ...  \
# 1838  Olivia Munn, Edgar Ramírez, Chris Coy, Eric Bana  ...
#
#                           Production House  \
# 1838  Jerry Bruckheimer Films, Screen Gems
#
#                                 Netflix Link  \
# 1838  https://www.netflix.com/watch/70299902
#
#                                  IMDb Link  \
# ...

# %%
data[ (data['Genre']=='Action, Adventure, Biography, Drama, History')]
# Out:
#                         Title                                         Genre  \
# 1638  In the Heart of the Sea  Action, Adventure, Biography, Drama, History
#
#      Languages Series or Movie  Hidden Gem Score  \
# 1638   English           Movie               2.6
#
#                                    Country Availability  Runtime    Director  \
# 1638  South Korea,Hungary,Brazil,Czech Republic,Ital...  > 2 hrs  Ron Howard
#
#                                                  Writer  \
# 1638  Amanda Silver, Nathaniel Philbrick, Rick Jaffa...
#
#                                                  Actors  ...  \
# 1638  Brendan Gleeson, Benjamin Walker, Chris Hemswo...  ...
#
#                                        Production House  \
# 1638  Imagine Entertainment, Roth Films, Cott Produc...
#
#                                 Netflix Link  \
# 1638  https://www.netflix.com/watch/80017529
#
#                                  IMDb Link  \
# 1638  https://www.imdb.com/title/tt1390411
#
# ...

# %%
data[ (data['Genre']=='Action, Adventure, Biography, Drama')]
# Out:
#         Title                                Genre               Languages  \
# 681  The Walk  Action, Adventure, Biography, Drama  English, French, Czech
#
#     Series or Movie  Hidden Gem Score  \
# 681           Movie               3.8
#
#                                   Country Availability  Runtime  \
# 681  Portugal,Switzerland,South Korea,Canada,Italy,...  > 2 hrs
#
#             Director                                             Writer  \
# 681  Robert Zemeckis  Christopher Browne, Robert Zemeckis, Philippe ...
#
#                                                 Actors  ... Production House  \
# 681  Mark Trafford, Guillaume Baillargeon, Joseph G...  ...      ImageMovers
#
#                                Netflix Link  \
# 681  https://www.netflix.com/watch/80048473
#
#                                 IMDb Link  \
# 681  https://www.imdb.com/title/tt3488710
#
#                                                Summary  IMDb Votes  \
# ...

# %%
data[ (data['Genre']=='Action, Adventure, Biography, Drama, Thriller')]
# Out:
#        Title                                          Genre         Languages  \
# 972  Everest  Action, Adventure, Biography, Drama, Thriller  English, Russian
#
#     Series or Movie  Hidden Gem Score Country Availability  Runtime  \
# 972           Movie               3.5       United Kingdom  > 2 hrs
#
#               Director                            Writer  \
# 972  Baltasar Kormákur  William Nicholson, Simon Beaufoy
#
#                                                 Actors  ...  \
# 972  Ang Phula Sherpa, Jason Clarke, Thomas M. Wrig...  ...
#
#                                       Production House  \
# 972  Working Title Films, Free State Pictures, RVK ...
#
#                                Netflix Link  \
# 972  https://www.netflix.com/watch/80046309
#
#                                 IMDb Link  \
# 972  https://www.imdb.com/title/tt2719848
#
#                                                Summary  IMDb Votes  \
# ...

# %%
action_genre = data[data['Genre'].str.contains("Action")]# Only Containing Ation Genre]
action_genre
# Out:
#                                               Title  \
# 1                                   Midnight Family
# 16                                          BuyBust
# 22                       Asura: The City of Madness
# 33                        Kundo: Age of the Rampant
# 35                        Mountain Patrol: Kekexili
# ...                                             ...
# 2104                             The Last Airbender
# 2108                         Paul Blart: Mall Cop 2
# 2110  In the Name of the King: A Dungeon Siege Tale
# 2112                                   The Avengers
# 2116                              Battlefield Earth
#
#                                           Genre          Languages  \
# 1             Documentary, Action, Crime, Drama            Spanish
# 16                      Action, Crime, Thriller  Filipino, Tagalog
# 22               Action, Crime, Drama, Thriller             Korean
# ...

# %%
data['Runtime'].max()
# Out:
# '> 2 hrs'

# %%
countries = data[data["Series or Movie"] == 'Movie']
countries["Country Availability"].value_counts()
# Out:
# South Korea                                                                                               78
# Canada                                                                                                    65
# United States                                                                                             56
# United Kingdom                                                                                            43
# Switzerland,Germany                                                                                       39
#                                                                                                           ..
# Hungary,France,Japan,Romania,Portugal,Spain,Czech Republic,Germany,Italy,Poland,Greece,Turkey,Slovakia     1
# Canada,Brazil,Portugal,India,Argentina,Mexico,Colombia,Spain                                               1
# Romania,Hungary,Lithuania,Czech Republic,Israel,Australia,Poland,Slovakia,Turkey                           1
# ...

# %%
data_1 = data.set_index("Title").select_dtypes('number')
data_1
# Out:
#                        Hidden Gem Score  IMDb Score  Rotten Tomatoes Score  \
# Title
# Gilberts Grim Revenge               8.7         7.5                     95
# Midnight Family                     8.5         7.4                     97
# Pick of the Litter                  8.3         7.5                     97
# Whose Streets?                      8.2         5.4                     98
# I Will Follow                       8.2         6.0                     82
# ...                                 ...         ...                    ...
# Fear Dot Com                        0.9         3.4                      3
# Daddy Day Camp                      0.8         3.1                      1
# Son of the Mask                     0.8         2.2                      6
# Battlefield Earth                   0.6         2.5                      3
# Baby Geniuses                       0.6         2.7                      2
#
#                        Metacritic Score  Awards Received  \
# ...

# %%
top15 = data_1.nlargest(15, columns = ["Hidden Gem Score", "Boxoffice (Dollar)"])
top15
# Out:
#                                Hidden Gem Score  IMDb Score  \
# Title
# Gilberts Grim Revenge                       8.7         7.5
# Midnight Family                             8.5         7.4
# Pick of the Litter                          8.3         7.5
# Whose Streets?                              8.2         5.4
# I Will Follow                               8.2         6.0
# Bethany Hamilton: Unstoppable               8.1         7.4
# Red Obsession                               8.1         6.7
# Dont Call Me Son                            8.1         6.8
# Menashe                                     8.0         6.5
# Middle of Nowhere                           8.0         6.4
# Be with Me                                  8.0         7.0
# All Saints                                  7.9         6.1
# The Last Sentence                           7.9         6.0
# Burden                                      7.8         6.6
# ...

# %%
top15 = data_1.nlargest(15, columns = ["Hidden Gem Score", "Boxoffice (Dollar)"])
top15.rank()
# Out:
#                                Hidden Gem Score  IMDb Score  \
# Title
# Gilberts Grim Revenge                      15.0        14.5
# Midnight Family                            14.0        12.5
# Pick of the Litter                         13.0        14.5
# Whose Streets?                             11.5         1.0
# I Will Follow                              11.5         3.5
# Bethany Hamilton: Unstoppable               9.0        12.5
# Red Obsession                               9.0         9.0
# Dont Call Me Son                            9.0        10.0
# Menashe                                     6.0         7.0
# Middle of Nowhere                           6.0         6.0
# Be with Me                                  6.0        11.0
# All Saints                                  3.5         5.0
# The Last Sentence                           3.5         3.5
# Burden                                      1.5         8.0
# ...

# %%
sns.set_theme(style="darkgrid")
sns.scatterplot(top15['Boxoffice (Dollar)'], top15['Hidden Gem Score'], 
                hue=top15["Boxoffice (Dollar)"], size=top15["Boxoffice (Dollar)"], 
                sizes=(160,250), alpha=1)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Boxoffice (Dollar)', ylabel='Hidden Gem Score'>

# %%
sns.set_theme(style="darkgrid")
sns.histplot(top15['Boxoffice (Dollar)'], kde=True, bins=14)
# Out:
# <AxesSubplot:xlabel='Boxoffice (Dollar)', ylabel='Count'>

# %%
data_1.columns
# Out:
# Index(['Hidden Gem Score', 'IMDb Score', 'Rotten Tomatoes Score',
#        'Metacritic Score', 'Awards Received', 'Awards Nominated For',
#        'Boxoffice (Dollar)', 'IMDb Votes'],
#       dtype='object')

# %%
sns.histplot(x= data_1["Hidden Gem Score"], y= data_1["Boxoffice (Dollar)"], bins=10, kde=True, multiple="dodge", shrink=.9)
# Out:
# <AxesSubplot:xlabel='Hidden Gem Score', ylabel='Boxoffice (Dollar)'>

# %%
sns.histplot(data_1[['Hidden Gem Score', 'IMDb Score', "Rotten Tomatoes Score", "Metacritic Score" ]], element="poly")
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.jointplot(x=top15["IMDb Votes"], y=top15["Boxoffice (Dollar)"], kind='reg')

# %%
sns.jointplot(x=top15["IMDb Votes"], y=top15["Boxoffice (Dollar)"], kind='kde', shade=True)

# %%
plt.figure(figsize=(14,10))
sns.stripplot(x=data["Runtime"] , y=data["Boxoffice (Dollar)"])
# Out:
# <AxesSubplot:xlabel='Runtime', ylabel='Boxoffice (Dollar)'>

# %%
# Directors and Actors

# %%
data.loc(data["Director"] == 'Nolan')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-1123f05e5dcf> in <module>
# ----> 1 data.loc(data["Director"] == 'Nolan')
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     605
#     606         if axis is not None:
# --> 607             axis = self.obj._get_axis_number(axis)
#     608         new_self.axis = axis
#     609         return new_self
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     458     def _get_axis_number(cls, axis: Axis) -> int:
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#     462             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1783
# ...
