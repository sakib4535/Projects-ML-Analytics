# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("netflix_price.csv")
data
# Out:
#           Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0       Argentina                4760             3154           1606
# 1         Austria                5640             3779           1861
# 2         Bolivia                4991             3155           1836
# 3        Bulgaria                6797             4819           1978
# 4           Chile                4994             3156           1838
# ..            ...                 ...              ...            ...
# 60        Ireland                6486             4515           1971
# 61    Switzerland                5506             3654           1852
# 62      Australia                6114             4050           2064
# 63        Denmark                4558             2978           1580
# 64  United States                5818             3826           1992
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                         3.74                           6.30
# ...

# %%
a = data["No. of TV Shows"].max()
b = data["No. of Movies"].max()
a,b
# Out:
# (5234, 2387)

# %%
a1 = data["No. of TV Shows"].min()
b1 = data["No. of Movies"].min()
a1,b1
# Out:
# (1675, 373)

# %%
plt.plot(data["No. of TV Shows"])
plt.plot(data["No. of Movies"])
plt.xlabel("Total Countries")
plt.ylabel("Number of Movies/TV Shows")
plt.legend(["Movies", "TV Shows"])

# %%
sns.pairplot(data=data)

# %%
sns.histplot(data["Total Library Size"], bins=15, kde=True)
# Out:
# <AxesSubplot:xlabel='Total Library Size', ylabel='Count'>

# %%
plt.plot(data["Cost Per Month - Basic ($)"])
plt.plot(data["Cost Per Month - Standard ($)"])
plt.plot(data["Cost Per Month - Premium ($)"])
plt.legend(["Basic", "Standard", "Premium"])

# %%
sns.heatmap(data.corr(), cmap='magma', annot=True)
# Out:
# <AxesSubplot:>

# %%
top10 = data.nlargest(10, columns=["Total Library Size"])
top10
# Out:
#            Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 8          Czechia                7325             5234           2091
# 36        Slovakia                7035             5055           1980
# 50         Hungary                6884             4802           2082
# 3         Bulgaria                6797             4819           1978
# 57  United Kingdom                6643             4551           2092
# 60         Ireland                6486             4515           1971
# 55       Lithuania                6462             4490           1972
# 10         Estonia                6456             4486           1970
# 48          Latvia                6450             4479           1971
# 18         Iceland                6387             4426           1961
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 8                         8.83                          11.49
# ...

# %%
bottom10 = data.nsmallest(10, columns=["Total Library Size"])
bottom10
# Out:
#           Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 7         Croatia                2274             1675            599
# 35     San Marino                2310             1937            373
# 23  Liechtenstein                3048             1712           1336
# 58      Indonesia                3887             2449           1438
# 26        Moldova                3937             2473           1464
# 47        Finland                4045             2638           1407
# 53         Sweden                4361             2973           1388
# 28         Norway                4528             2955           1573
# 63        Denmark                4558             2978           1580
# 41         Turkey                4639             2930           1709
#
#     Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 7                         9.03                          11.29
# 35                        9.03                          14.67
# ...

# %%
plt.figure(figsize=(14,6))
sns.barplot(top10["Country"], top10["Total Library Size"])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='Total Library Size'>

# %%
plt.figure(figsize=(14,6))
sns.barplot(bottom10["Country"], bottom10["Total Library Size"])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='Total Library Size'>

# %%
sns.barplot(top10["No. of Movies"], top10["Country"])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='No. of Movies', ylabel='Country'>

# %%
sns.barplot(top10["No. of TV Shows"], top10["Country"])
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='No. of TV Shows', ylabel='Country'>

# %%
plt.figure(figsize=(14,10))
plt.violinplot(top10["Cost Per Month - Basic ($)"])
plt.violinplot(top10["Cost Per Month - Standard ($)"])
plt.violinplot(top10["Cost Per Month - Premium ($)"])
plt.ylabel("Subscription Cost")
plt.legend()
# Out:
# No handles with labels found to put in legend.
